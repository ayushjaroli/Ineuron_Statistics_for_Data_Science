# %% [markdown]
# #### 1. Write the Gaussian Distribution empirical formula.

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# #### 2. What is the Z-score, and why is it important?

# %% [markdown]
# #####  The Z score is the number of standard deviations by which the value of a raw score (i.e., an observed value or data point) is above or below the mean value of what is being observed or measured. Raw scores above the mean have positive standard scores, while those below the mean have negative standard scores. The  Z-score is a very useful statistic because it (a) allows us to calculate the probability of a score occurring within our normal distribution and (b) enables us to compare two scores that are from different normal distributions.

# %% [markdown]
# #### 3. What is an outlier, exactly?

# %% [markdown]
# ##### Values that lies beyond lower and upper fence is called outliers.

# %% [markdown]
# #### 4. What are our options for dealing with outliers in our dataset?

# %% [markdown]
# ##### Certain ways to deal with outliers are
# ##### a)Trimming/removing the outlier
# ##### b)Quantile based flooring and capping
# ##### c)Mean/Median imputation

# %% [markdown]
# #### 5. Write the sample and population variances equations and explain Bessel Correction.

# %% [markdown]
# ![population-variance.png](attachment:population-variance.png)

# %% [markdown]
# ##### (n-1) is known as Bessel's correction. This method corrects the biased estimation of variance in population data.
